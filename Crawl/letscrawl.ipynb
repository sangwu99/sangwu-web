# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sangw\\Desktop\\test\\data-portal-crawling\\sangwu-web\\Crawl'

# %%
from bs4 import BeautifulSoup


from urllib.request import urlopen

# %%
url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid1=105&sid2=731'
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=731" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="다양한 기사 정보를 제공합니다." property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="다양한 기사 정보를 제공합니다." name="twitter:description"/>
# <title>IT/과학 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.flash';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Sat Jul 16 21:34:13 KST 2022";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li class="on"><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>07</strong>.<strong>16</strong><span class="day">(토)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h7"><a class="nclicks(lmn_sci.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105">IT/과학</a></h2>
# <ul class="nav">
# <li class="on"><a class="snb_s43 nclicks(lmn_sci.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=731">모바일 <span class="blind">선택됨</span></a></li>
# <li><a class="snb_s44 nclicks(lmn_sci.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=226">인터넷/SNS </a></li>
# <li><a class="snb_s45 nclicks(lmn_sci.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=227">통신/뉴미디어 </a></li>
# <li><a class="snb_s46 nclicks(lmn_sci.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=230">IT 일반 </a></li>
# <li><a class="snb_s48 nclicks(lmn_sci.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=732">보안/해킹 </a></li>
# <li><a class="snb_s47 nclicks(lmn_sci.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=283">컴퓨터 </a></li>
# <li><a class="snb_s50 nclicks(lmn_sci.mnl,,7)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=229">게임/리뷰 </a></li>
# <li><a class="snb_s49 nclicks(lmn_sci.mnl,,8)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=105&amp;sid2=228">과학 일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_sci.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_sci.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_header newsflash_header">
# <h3>모바일</h3>
# </div>
# <div class="list_body newsflash_body">
# <ul class="type06_headline">
# <li>
# <dl>
# <dt>
# <a href="https://n.news.naver.com/mnews/article/119/0002621498?sid=105">
# 								 [부고] 박승정 지디넷코리아 편집국장 본인상
# 								</a>
# </dt>
# <dd>
# <span class="lede">▲박승정 지디넷코리아 편집국장 별세, 박영서‧박성서 부친상, 김정희 남편상, 박승식‧박승대 형제상=16일  …</span>
# <span class="writing">데일리안</span>
# <span class="date is_outdated">4시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a href="https://n.news.naver.com/mnews/article/003/0011308396?sid=105">
# <img alt="한국, 올해 국제수학올림피아드서 2위…金 3명·銀 3명 '전원 메달'" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/003/2022/07/16/11308396.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a href="https://n.news.naver.com/mnews/article/003/0011308396?sid=105">
# 								 한국, 올해 국제수학올림피아드서 2위…金 3명·銀 3명 '전원 메달'
# 								</a>
# </dt>
# <dd>
# <span class="lede">기사내용 요약 104개국 학생 589명 참가…중국 1위·미국 3위 최우진 등 학생 6명 전원 서울과학고 출신 허준이 교수 필즈상 …</span>
# <span class="writing">뉴시스</span>
# <span class="date is_outdated">5시간전	</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a href="https
jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a href="https://n.news.naver.com/mnews/article/003/0011307713?sid=105">
# 								 尹 정부 7대 우주강국 비전 담은 5개년 '우주개발진흥기본계획' 12월 발표
# 								</a>
# </dt>
# <dd>
# <span class="lede">기사내용 요약 과기부, '한국판 NASA' 항공우주청 설립 위해 기능·역할 등 의견 수렴 중 [서울=뉴시스]이진영 기자 = 윤석 …</span>
# <span class="writing">뉴시스</span>
# <span class="date is_outdated">1일전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a href="https://n.news.naver.com/mnews/article/003/0011307709?sid=105">
# <img alt="文정부 간판 민관합동기구 '4차산업혁명위원회' 결국 역사속으로" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/003/2022/07/15/11307709.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a href="https://n.news.naver.com/mnews/article/003/0011307709?sid=105">
# 								 文정부 간판 민관합동기구 '4차산업혁명위원회' 결국 역사속으로
# 								</a>
# </dt>
# <dd>
# <span class="lede">기사내용 요약 과기부, 관련 위원회 28개 중 4차위 등 11개 폐지 보고 "데이터3법 문제해결 등이 성과 "강력한 권한 없어  …</span>
# <span class="writing">뉴시스</span>
# <span class="date is_outdated">1일전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a href="https://n.news.naver.com/mnews/article/003/0011307705?sid=105">
# <img alt="과기장관+기업 CEO, 민관협의체 구성…'초격차 전략기술' 방향타 잡는다" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/003/2022/07/15/11307705.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a href="https://n.news.naver.com/mnews/article/003/0011307705?sid=105">
# 								 과기장관+기업 CEO, 민관협의체 구성…'초격차 전략기술' 방향타 잡는다
# 								</a>
# </dt>
# <dd>
# <span class="lede">기사내용 요약 "정책 기획 단계부터 기업 의견 전극 반영" 기존 10개에 +α를 더해 '초격차 전략기술' 오는 9월 선정 [서울 …</span>
# <span class="writing">뉴시스</span>
# <span class="date is_outdated">1일전</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a href="https://n.news.naver.com/mnews/article/003/0011307691?sid=105">
# <img alt="ETRI 김명준·원자력연 박원석 원장 연임 불발" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/003/2022/07/15/11307691.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a href="https://n.news.naver.com/mnews/article/003/0011307691?sid=105">
# 								 ETRI 김명준·원자력연 박원석 원장 연임 불발
# 								</a>
# </dt>
# <dd>
# <span class="lede">기사내용 요약 국가과학기술연구회, 재선임 심의 결과 발표 한국전자통신연구원(ETRI) 김명준 원장과 한국원자력연구원 박원석 원장 …</span>
# <span class="writing">뉴시스</span>
# <span class="date is_outdated">1일전</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paging">
# <strong>1</strong>
# </div>
# <h4 class="blind">뉴스 이전날짜 더보기 링크모음</h4>
# <div class="pagenavi_day">
# <span class="viewday">7월16일(토)</span><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LS2D&amp;mid=shm&amp;sid2=731&amp;sid1=105&amp;date=20220715">7월15일(금)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LS2D&amp;mid=shm&amp;sid2=731&amp;sid1=105&amp;date=20220714">7월14일(목)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LS2D&amp;mid=shm&amp;sid2=731&amp;sid1=105&amp;date=20220713">7월13일(수)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LS2D&amp;mid=shm&amp;sid2=731&amp;sid1=105&amp;date=20220712">7월12일(화)</a></div>
# <script type="text/javascript">
# window.onload = function() {
# 	var selected_item = jindo.$('_');
# 	if (selected_item != null) {
# 		selected_item.className = "highlight";
# 		news.section.ScrollingManager.scroll('');
# 	}
# }
# news.section.MainIssueCollectManager.init({
# 	mediaOneDomain : 'https://n.news.naver.com'
# });
# news.util.CommentListCountManager.view();
a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/005/0001540384?sid=105" title="국제수학올림피아드 韓고교생 6명 전원 메달…2위 쾌거">국제수학올림피아드 韓고교생 6명 전원 메달…2위 쾌거</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/031/0000685771?sid=105" title="'밤토끼' 없어도 웹툰 매년 불법공유 증가…&quot;사이버 범죄 처벌해야&quot; [IT돋보기]">'밤토끼' 없어도 웹툰 매년 불법공유 증가…"사이버 범죄 처벌해야" [IT돋보기]</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011308491?sid=102" title="인하대 여대생 강간치사 혐의 동급생에 구속영장 신청">인하대 여대생 강간치사 혐의 동급생에 구속영장 신청</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003287657?sid=102" title="[현장]3년만에 뜬 ‘무지개 깃발’, 서울광장에 돌아온 퀴어축제">[현장]3년만에 뜬 ‘무지개 깃발’, 서울광장에 돌아온 퀴어축제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/020/0003440273?sid=102" title="[단독]하청노조 파업 장기화에 대우조선, 다음 주 일부 휴업 전환">[단독]하청노조 파업 장기화에 대우조선, 다음 주 일부 휴업 전환</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001677340?sid=103" title="[MBN뉴스센터 날씨]내일도 내륙 강한 소나기…남부 중심 무더위 계속">[MBN뉴스센터 날씨]내일도 내륙 강한 소나기…남부 중심 무더위 계속</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003664857?sid=103" title='[파고들기]코로나 재확산…공연계 "예의주시, 자체 방역 만전"'>[파고들기]코로나 재확산…공연계 "예의주시, 자체 방역 만전"</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/175236270_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183426027_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
# new news.flash.SubsectionLayerManager('n.f.subsection.layer');
#
#
# new MyFeed()
#     .init({
#         sMyFeedUrl: 'https://me.naver.com/tab/feed/news.nhn',
#         apiUrlMap: {
#             'check': 'https://apis.naver.com/newsweb/media/subscribedChannels?hasFollowerCount=true',
#             'follow': 'https://apis.naver.com/newsweb/media/doSubscribe',
#             'unfollow': 'https://apis.naver.com/newsweb/media/cancelSubscribe'
#         }
#     });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>>

# %%
title = soup.find_all('dt', class_=None)
titles=[]

for n in title:
    a = n.get_text()
    titles.append(a)

print(titles)
# Out:
# ['\n\n\t\t\t\t\t\t\t\t [부고] 박승정 지디넷코리아 편집국장 본인상\n\t\t\t\t\t\t\t\t\n', "\n\n\t\t\t\t\t\t\t\t 한국, 올해 국제수학올림피아드서 2위…金 3명·銀 3명 '전원 메달'\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t [위클리 스마트] '하늘 나는 미래 먹거리' UAM 사업 나선 통신3사\n\t\t\t\t\t\t\t\t\n", '\n\n\t\t\t\t\t\t\t\t "이것이 갤럭시Z플립4 보라 퍼플".. 추정 사진 등장\n\t\t\t\t\t\t\t\t\n', "\n\n\t\t\t\t\t\t\t\t 美 공화 의원들, 틱톡에 추가자료 요청…'안보위협' 압박 강화\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t 속 보이는 '폰원' 잘 팔릴까\n\t\t\t\t\t\t\t\t\n", '\n\n\t\t\t\t\t\t\t\t 5G 중간요금제 적정안은?…고민 깊어지는 정부·업계\n\t\t\t\t\t\t\t\t\n', "\n\n\t\t\t\t\t\t\t\t [잇써보니] '투명폰' 낫싱 폰원, 독특한 디자인 속 평범함\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t SKT, '2022 대한민국 드론·UAM 박람회' 참가\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t SKT, '2022 대한민국 드론·UAM 박람회' 참가\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t SKT, '2022 대한민국 드론·UAM 박람회' 참가\n\t\t\t\t\t\t\t\t\n", '\n\n\t\t\t\t\t\t\t\t "게임은 오래하면 중독이고, 드라마는 하루종일 몰아봐도 괜찮고?"(종합)\n\t\t\t\t\t\t\t\t\n', '\n\n\t\t\t\t\t\t\t\t 삼성전자 세탁기 작동 중 \'쾅\'..."원인 조사할 것"\n\t\t\t\t\t\t\t\t\n', "\n\n\t\t\t\t\t\t\t\t 항공우주청 신설 추진…R&D 예타 '1000억 이상'으로 완화\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t [이주의 전자뉴스] 노트북 업계, 기업 시장 공략 '점화'…신제품 다각화\n\t\t\t\t\t\t\t\t\n", '\n\n\t\t\t\t\t\t\t\t 과기부, 韓 기업들 글로벌 기술패권 선점 위해 밀착 지원사격(종합)\n\t\t\t\t\t\t\t\t\n', "\n\n\t\t\t\t\t\t\t\t 尹 정부 7대 우주강국 비전 담은 5개년 '우주개발진흥기본계획' 12월 발표\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t 文정부 간판 민관합동기구 '4차산업혁명위원회' 결국 역사속으로\n\t\t\t\t\t\t\t\t\n", "\n\n\t\t\t\t\t\t\t\t 과기장관+기업 CEO, 민관협의체 구성…'초격차 전략기술' 방향타 잡는다\n\t\t\t\t\t\t\t\t\n", '\n\n\t\t\t\t\t\t\t\t ETRI 김명준·원자력연 박원석 원장 연임 불발\n\t\t\t\t\t\t\t\t\n']

# %%
import re

# %%
p = re.compile('[a-z]+')

# %%
m = p.match("python")

# %%
m = p.search("3 python")

# %%
print(m)
# Out:
# <re.Match object; span=(2, 8), match='python'>

# %%
result = p.findall("3 5 life is too short")
print(result)
# Out:
# ['life', 'is', 'too', 'short']

# %%
result = p.finditer("life is too short")
print(result)
# Out:
# <callable_iterator object at 0x00000269C43E3580>

# %%
for i in result:
    print(i)
# Out:
# <re.Match object; span=(0, 4), match='life'>
# <re.Match object; span=(5, 7), match='is'>
# <re.Match object; span=(8, 11), match='too'>
# <re.Match object; span=(12, 17), match='short'>

# %%
m = p.match("python")

# %%
m.group()
# Out:
# 'python'

# %%
m.span()
# Out:
# (0, 6)

# %%
m = p.search("3 python")
print(m.group())
print(m.span())
# Out:
# python
# (2, 8)
